# %%
import requests

response = requests.get("https://api.flightapi.io/schedule/67cabf7ed8fa5ab514772bf9?mode=departures&iata=EDI&day=1")
print(response.json())
# Out:
# {'airport': {'pluginData': {'details': {'name': 'Edinburgh Airport', 'code': {'iata': 'EDI', 'icao': 'EGPH'}, 'delayIndex': {'arrivals': 0.42, 'departures': 0.71}, 'stats': {'arrivals': {'delayIndex': 0.42, 'delayAvg': 5, 'percentage': {'delayed': 0.1, 'canceled': 0, 'trend': 'down'}, 'recent': {'delayIndex': 0.42, 'delayAvg': 5, 'percentage': {'delayed': 0.1, 'canceled': 0, 'trend': 'down'}, 'quantity': {'onTime': 19, 'delayed': 2, 'canceled': 0}}, 'today': {'percentage': {'delayed': 0.01, 'canceled': 0}, 'quantity': {'onTime': 30, 'delayed': 2, 'canceled': 0}}, 'yesterday': {'percentage': {'delayed': 0.09, 'canceled': 0.01}, 'quantity': {'onTime': 135, 'delayed': 14, 'canceled': 2}}, 'tomorrow': {'percentage': {'canceled': 0}, 'quantity': {'canceled': 0}}}, 'departures': {'delayIndex': 0.71, 'delayAvg': 8, 'percentage': {'delayed': 0.36, 'canceled': 0, 'trend': 'up'}, 'recent': {'delayIndex': 0.71, 'delayAvg': 8, 'percentage': {'delayed': 0.36, 'canceled': 0, 'trend': 'up'}, 'quantity': {'onTime': 14, 'delayed': 8, 'canceled': 0}}, 'today': {'percentage': {'delayed': 0.09, 'canceled': 0}, 'quantity': {'onTime': 37, 'delayed': 16, 'canceled': 0}}, 'yesterday': {'percentage': {'delayed': 0.29, 'canceled': 0.01}, 'quantity': {'onTime': 107, 'delayed': 44, 'canceled': 1}}, 'tomorrow': {'percentage': {'canceled': 0}, 'quantity': {'canceled': 0}}}}, 'position': {'latitude': 55.950001, 'longitude': -3.3725, 'elevation': 135, 'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235}, 'region': {'city': 'Edinburgh'}}, 'timezone': {'name': 'Europe/London', 'offset': 0, 'abbr': 'GMT', 'abbrName': 'Greenwich Mean Time', 'isDst': False}, 'url': {'homepage': 'http://www.edinburghairport.com/', 'webcam': 'https://airportwebcams.net/edinburgh-airport-webcam/', 'wikipedia': 'https://en.wikipedia.org/wiki/Edinburgh_Airport'}, 'airportImages': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/911307_1722256620_tb.jpg', 'link': 'https://www.jetphotos.com/photo/11427326', 'copyright': 'Lonely Neutrino', 'source': 'Jetphotos.com'}, {'src': 'https://cdn.jetphotos.com/200/6/18784_1425933101_tb.jpg', 'link': 'https://www.jetphotos.com/photo/7995810', 'copyright': 'Roger Oldfield', 'source': 'Jetphotos.com'}], 'medium': [{'src': 'https://cdn.jetphotos.com/400/6/911307_1722256620.jpg', 'link': 'https://www.jetphotos.com/photo/11427326', 'copyright': 'Lonely Neutrino', 'source': 'Jetphotos.com'}, {'src': 'https://cdn.jetphotos.com/400/6/18784_1425933101.jpg', 'link': 'https://www.jetphotos.com/photo/7995810', 'copyright': 'Roger Oldfield', 'source': 'Jetphotos.com'}], 'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/911307_1722256620.jpg', 'link': 'https://www.jetphotos.com/photo/11427326', 'copyright': 'Lonely Neutrino', 'source': 'Jetphotos.com'}, {'src': 'https://cdn.jetphotos.com/640cb/6/18784_1425933101.jpg', 'link': 'https://www.jetphotos.com/photo/7995810', 'copyright': 'Roger Oldfield', 'source': 'Jetphotos.com'}]}, 'visible': True}, 'flightdiary': {'url': '/data/airports/edi/reviews', 'ratings': {'avg': 3.93, 'total': 3194}, 'comment': [{'content': "I just had a backpack, so it was straight to security for me. There was a larger queue than the last time, but I was still through in six minutes. No doubt due in large part to no longer requiring to take things from bags.\r\nI was leaving from Gate 21, which is around the corner. I had WiFi connection previously, but when I got to the gate I had none. I don't know if it was a wider issue or just an issue with the gates furthest away from the main body of the departure lounge.", 'author': {'facebookId': None, 'name': 'AlphaMikeEcho'}, 'timestamp': 1738781399}], 'reviews': 143, 'evaluation': 79}, 'schedule': {'departures': {'item': {'current': 100, 'total': 237, 'limit': 100}, 'page': {'current': 1, 'total': 3}, 'timestamp': 1741340640, 'data': [{'flight': {'identification': {'id': None, 'row': 5630662448, 'number': {'default': 'BA1441', 'alternative': None}, 'callsign': 'SHT9Z', 'co ...

# %%
import pprint
arrivals = response.json()
# pprint.pp(arrivals)

arrivals.keys()
# Out:
# dict_keys(['airport', 'airlines', 'aircraftImages'])

# %%
pprint.pp(arrivals)

# %%
pprint.pp(arrivals['airport']['pluginData']['schedule']['departures'].keys())
# Out:
# dict_keys(['item', 'page', 'timestamp', 'data'])

# %%
pprint.pp(arrivals['airport']['pluginData']['schedule']['departures']['data'][0]['flight'])
# Out:
# {'identification': {'id': None,
#                     'row': 5630662448,
#                     'number': {'default': 'BA1441', 'alternative': None},
#                     'callsign': 'SHT9Z',
#                     'codeshare': ['AA6734',
#                                   'AY5942',
#                                   'IB3730',
#                                   'QF3560',
#                                   'QR6283']},
#  'status': {'live': False,
#             'text': 'Estimated dep 10:08',
#             'icon': 'yellow',
#             'estimated': None,
#             'ambiguous': False,
#             'generic': {'status': {'text': 'estimated',
#                                    'type': 'departure',
#                                    'color': 'yellow',
#                                    'diverted': None},
#                         'eventTime': {'utc': 1741342080, 'local': 1741342080}}},
#  'aircraft': {'model': {'code': 'A20N', 'text': 'Airbus A320-251N'},
#               'registration': 'G-TTNL',
#               'country': {'id': 235,
#                           'name': 'United Kingdom',
#                           'alpha2': 'GB',
#                           'alpha3': 'GBR'},
#               'hex': '40792F',
#               'restricted': False,
#               'serialNo': None,
#               'age': {'availability': True},
#               'availability': {'serialNo': True, 'age': True}},
#  'owner': {'name': 'British Airways',
#            'code': {'iata': 'BA', 'icao': 'BAW'},
#            'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/5.png'},
#  'airline': {'name': 'British Airways',
#              'code': {'iata': 'BA', 'icao': 'BAW'},
#              'short': 'British Airways'},
#  'airport': {'origin': {'timezone': {'name': 'Europe/London',
#                                      'offset': 0,
#                                      'abbr': 'GMT',
#                                      'abbrName': 'Greenwich Mean Time',
#                                      'isDst': False},
#                         'info': {'terminal': None,
#                                  'baggage': None,
#                                  'gate': None}},
#              'destination': {'code': {'iata': 'LHR', 'icao': 'EGLL'},
#                              'timezone': {'name': 'Europe/London',
#                                           'offset': 0,
#                                           'abbr': 'GMT',
#                                           'abbrName': 'Greenwich Mean Time',
#                                           'isDst': False},
#                              'info': {'terminal': '5',
#                                       'baggage': None,
#                                       'gate': None},
#                              'name': 'London Heathrow Airport',
#                              'position': {'latitude': 51.471626,
#                                           'longitude': -0.467081,
#                                           'country': {'name': 'United Kingdom',
#                                                       'code': 'GB',
#                                                       'id': 235},
#                                           'region': {'city': 'London'}},
#                              'visible': True},
#              'real': None},
#  'time': {'scheduled': {'departure': 1741341000, 'arrival': 1741346700},
#           'real': {'departure': None, 'arrival': None},
#           'estimated': {'departure': 1741342080, 'arrival': None},
#           'other': {'eta': None, 'duration': None}}}

# %%
# import json
# json.dump(arrivals, open(, 'wb'))
# # data = json.load(open(filename))

filename_airports = "data_airline_edi_7mar2025.json"

import json 
   

# Convert and write JSON object to file
def save_data(filename, data):
    with open(filename, "w") as outfile: 
        json.dump(data, outfile)

save_data(filename, arrivals )

def load_file(filename):
    data = json.load(open(filename))
    return data

load_file(filename_airports)
# Out:
# {'pluginData': {'details': {'name': 'Edinburgh Airport',
#    'code': {'iata': 'EDI', 'icao': 'EGPH'},
#    'delayIndex': {'arrivals': 0.42, 'departures': 0.71},
#    'stats': {'arrivals': {'delayIndex': 0.42,
#      'delayAvg': 5,
#      'percentage': {'delayed': 0.1, 'canceled': 0, 'trend': 'down'},
#      'recent': {'delayIndex': 0.42,
#       'delayAvg': 5,
#       'percentage': {'delayed': 0.1, 'canceled': 0, 'trend': 'down'},
#       'quantity': {'onTime': 19, 'delayed': 2, 'canceled': 0}},
#      'today': {'percentage': {'delayed': 0.01, 'canceled': 0},
#       'quantity': {'onTime': 30, 'delayed': 2, 'canceled': 0}},
#      'yesterday': {'percentage': {'delayed': 0.09, 'canceled': 0.01},
#       'quantity': {'onTime': 135, 'delayed': 14, 'canceled': 2}},
#      'tomorrow': {'percentage': {'canceled': 0}, 'quantity': {'canceled': 0}}},
#     'departures': {'delayIndex': 0.71,
#      'delayAvg': 8,
#      'percentage': {'delayed': 0.36, 'canceled': 0, 'trend': 'up'},
#      'recent': {'delayIndex': 0.71,
#       'delayAvg': 8,
#       'percentage': {'delayed': 0.36, 'canceled': 0, 'trend': 'up'},
#       'quantity': {'onTime': 14, 'delayed': 8, 'canceled': 0}},
#      'today': {'percentage': {'delayed': 0.09, 'canceled': 0},
#       'quantity': {'onTime': 37, 'delayed': 16, 'canceled': 0}},
#      'yesterday': {'percentage': {'delayed': 0.29, 'canceled': 0.01},
#       'quantity': {'onTime': 107, 'delayed': 44, 'canceled': 1}},
#      'tomorrow': {'percentage': {'canceled': 0},
#       'quantity': {'canceled': 0}}}},
#    'position': {'latitude': 55.950001,
#     'longitude': -3.3725,
#     'elevation': 135,
#     'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#     'region': {'city': 'Edinburgh'}},
#    'timezone': {'name': 'Europe/London',
#     'offset': 0,
#     'abbr': 'GMT',
#     'abbrName': 'Greenwich Mean Time',
#     'isDst': False},
#    'url': {'homepage': 'http://www.edinburghairport.com/',
#     'webcam': 'https://airportwebcams.net/edinburgh-airport-webcam/',
#     'wikipedia': 'https://en.wikipedia.org/wiki/Edinburgh_Airport'},
#    'airportImages': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/911307_1722256620_tb.jpg',
#       'link': 'https://www.jetphotos.com/photo/11427326',
#       'copyright': 'Lonely Neutrino',
#       'source': 'Jetphotos.com'},
#      {'src': 'https://cdn.jetphotos.com/200/6/18784_1425933101_tb.jpg',
#       'link': 'https://www.jetphotos.com/photo/7995810',
#       'copyright': 'Roger Oldfield',
#       'source': 'Jetphotos.com'}],
#     'medium': [{'src': 'https://cdn.jetphotos.com/400/6/911307_1722256620.jpg',
#       'link': 'https://www.jetphotos.com/photo/11427326',
#       'copyright': 'Lonely Neutrino',
#       'source': 'Jetphotos.com'},
#      {'src': 'https://cdn.jetphotos.com/400/6/18784_1425933101.jpg',
#       'link': 'https://www.jetphotos.com/photo/7995810',
#       'copyright': 'Roger Oldfield',
#       'source': 'Jetphotos.com'}],
#     'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/911307_1722256620.jpg',
#       'link': 'https://www.jetphotos.com/photo/11427326',
#       'copyright': 'Lonely Neutrino',
#       'source': 'Jetphotos.com'},
#      {'src': 'https://cdn.jetphotos.com/640cb/6/18784_1425933101.jpg',
#       'link': 'https://www.jetphotos.com/photo/7995810',
#       'copyright': 'Roger Oldfield',
#       'source': 'Jetphotos.com'}]},
#    'visible': True},
#   'flightdiary': {'url': '/data/airports/edi/reviews',
#    'ratings': {'avg': 3.93, 'total': 3194},
#    'comment': [{'content': "I just had a backpack, so it was straight to security for me. There was a larger queue than the last time, but I was still through in six minutes. No doubt due in large part to no longer requiring to take things from bags.\r\nI was leaving from Gate 21, which is around the corner. I had WiFi connection previously, but when I got to the gate I had none. I don't know if it was a wider issue or just an issue with the gates furthest away from the main body of the departure lounge.",
#      'author': {'facebookId': None, 'name': 'AlphaMikeEcho'},
#      'timestamp': 1738781399}],
#    'reviews': 143,
#    'evaluation': 79},
#   'schedule': {'departures': {'item': {'current': 100,
#      'total': 237,
#      'limit': 100},
#     'page': {'current': 1, 'total': 3},
#     'timestamp': 1741340640,
#     'data': [{'flight': {'identification': {'id': None,
#         'row': 5630662448,
#         'number': {'default': 'BA1441', 'alternative': None},
#         'callsign': 'SHT9Z',
#         'codeshare': ['AA6734', 'AY5942', 'IB3730', 'QF3560', 'QR6283']},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:08',
#         'icon': 'yellow',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'yellow',
#           'diverted': None},
#          'eventTime': {'utc': 1741342080, 'local': 1741342080}}},
#        'aircraft': {'model': {'code': 'A20N', 'text': 'Airbus A320-251N'},
#         'registration': 'G-TTNL',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '40792F',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/5.png'},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LHR', 'icao': 'EGLL'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '5', 'baggage': None, 'gate': None},
#          'name': 'London Heathrow Airport',
#          'position': {'latitude': 51.471626,
#           'longitude': -0.467081,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741341000, 'arrival': 1741346700},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741342080, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630874374,
#         'number': {'default': 'U23293', 'alternative': None},
#         'callsign': 'EZY85RN',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 09:55',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741341300, 'local': 1741341300}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZTG',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406011',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'GVA', 'icao': 'LSGG'},
#          'timezone': {'name': 'Europe/Zurich',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': '1', 'baggage': '2', 'gate': None},
#          'name': 'Geneva International Airport',
#          'position': {'latitude': 46.23806,
#           'longitude': 6.10895,
#           'country': {'name': 'Switzerland', 'code': 'CH', 'id': 216},
#           'region': {'city': 'Geneva'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741341300, 'arrival': 1741349400},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741341300, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630873569,
#         'number': {'default': 'U2311', 'alternative': None},
#         'callsign': 'EZY87HG',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:15',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741342500, 'local': 1741342500}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZWY',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406B91',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'STN', 'icao': 'EGSS'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '1', 'baggage': None, 'gate': None},
#          'name': 'London Stansted Airport',
#          'position': {'latitude': 51.884998,
#           'longitude': 0.235,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741342500, 'arrival': 1741347300},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741342500, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630664042,
#         'number': {'default': 'BA8715', 'alternative': 'CJ8715'},
#         'callsign': 'CFE57J',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:20',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741342800, 'local': 1741342800}}},
#        'aircraft': {'model': {'code': 'E190', 'text': 'Embraer E190SR'},
#         'registration': 'G-LCYV',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406D4E',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'BA CityFlyer',
#         'code': {'iata': 'CJ', 'icao': 'CFE'},
#         'logo': None},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LCY', 'icao': 'EGLC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': '03', 'gate': None},
#          'name': 'London City Airport',
#          'position': {'latitude': 51.505268,
#           'longitude': 0.055278,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741342800, 'arrival': 1741348200},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741342800, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630874922,
#         'number': {'default': 'U26566', 'alternative': None},
#         'callsign': 'EZY73GD',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:25',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741343100, 'local': 1741343100}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EJCE',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407E61',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LGW', 'icao': 'EGKK'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': 'S', 'baggage': None, 'gate': None},
#          'name': 'London Gatwick Airport',
#          'position': {'latitude': 51.148048,
#           'longitude': -0.19027,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741343100, 'arrival': 1741348500},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741343100, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630803267,
#         'number': {'default': 'LM323', 'alternative': None},
#         'callsign': 'LOG24J',
#         'codeshare': ['BA4103', 'SI7323']},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:48',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344480, 'local': 1741344480}}},
#        'aircraft': {'model': {'code': 'E145', 'text': 'Embraer ERJ-145EP'},
#         'registration': 'G-SAJK',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '4007DC',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'logo': None},
#        'airline': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'short': 'Loganair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'SOU', 'icao': 'EGHI'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Southampton Airport',
#          'position': {'latitude': 50.95026,
#           'longitude': -1.3568,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Southampton'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741343700, 'arrival': 1741348800},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344480, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630874384,
#         'number': {'default': 'U23323', 'alternative': None},
#         'callsign': 'EZY43JU',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:35',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741343700, 'local': 1741343700}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZOT',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406E65',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'CPH', 'icao': 'EKCH'},
#          'timezone': {'name': 'Europe/Copenhagen',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': '3', 'baggage': None, 'gate': None},
#          'name': 'Copenhagen Airport',
#          'position': {'latitude': 55.616959,
#           'longitude': 12.645637,
#           'country': {'name': 'Denmark', 'code': 'DK', 'id': 61},
#           'region': {'city': 'Copenhagen'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741343700, 'arrival': 1741350600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741343700, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630874391,
#         'number': {'default': 'U23319', 'alternative': None},
#         'callsign': 'EZY17QR',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:35',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741343700, 'local': 1741343700}}},
#        'aircraft': {'model': {'code': 'A20N', 'text': 'Airbus A320-251N'},
#         'registration': 'G-UZEE',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '40815C',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'HRG', 'icao': 'HEGN'},
#          'timezone': {'name': 'Africa/Cairo',
#           'offset': 7200,
#           'abbr': 'EET',
#           'abbrName': 'Eastern European Time',
#           'isDst': False},
#          'info': {'terminal': '1', 'baggage': None, 'gate': None},
#          'name': 'Hurghada International Airport',
#          'position': {'latitude': 27.17831,
#           'longitude': 33.799431,
#           'country': {'name': 'Egypt', 'code': 'EG', 'id': 66},
#           'region': {'city': 'Hurghada'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741343700, 'arrival': 1741364100},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741343700, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630677199,
#         'number': {'default': 'D83503', 'alternative': None},
#         'callsign': 'NSZ3503',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:40',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344000, 'local': 1741344000}}},
#        'aircraft': {'model': {'code': 'B738', 'text': 'Boeing 737-8JP'},
#         'registration': 'SE-RRO',
#         'country': {'id': 215,
#          'name': 'Sweden',
#          'alpha2': 'SE',
#          'alpha3': 'SWE'},
#         'hex': '4ACA4F',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Norwegian Air Sweden',
#         'code': {'iata': 'D8', 'icao': 'NSZ'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/1278.png'},
#        'airline': {'name': 'Norwegian (Otto Sverdrup Livery)',
#         'code': {'iata': 'DY', 'icao': 'NOZ'},
#         'short': 'Norwegian'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'CPH', 'icao': 'EKCH'},
#          'timezone': {'name': 'Europe/Copenhagen',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': '3', 'baggage': None, 'gate': None},
#          'name': 'Copenhagen Airport',
#          'position': {'latitude': 55.616959,
#           'longitude': 12.645637,
#           'country': {'name': 'Denmark', 'code': 'DK', 'id': 61},
#           'region': {'city': 'Copenhagen'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344000, 'arrival': 1741350300},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344000, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630712140,
#         'number': {'default': 'FR3732', 'alternative': 'MW3732'},
#         'callsign': 'RYR4GM',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:50',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344600, 'local': 1741344600}}},
#        'aircraft': {'model': {'code': 'B738', 'text': 'Boeing 737-8AS'},
#         'registration': '9H-QDU',
#         'country': {'id': 136,
#          'name': 'Malta',
#          'alpha2': 'MT',
#          'alpha3': 'MLT'},
#         'hex': '4D226A',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Malta Air',
#         'code': {'iata': 'MW', 'icao': 'MAY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/1530.png'},
#        'airline': {'name': 'Ryanair',
#         'code': {'iata': 'FR', 'icao': 'RYR'},
#         'short': 'Ryanair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'ORK', 'icao': 'EICK'},
#          'timezone': {'name': 'Europe/Dublin',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': '3', 'gate': '1A'},
#          'name': 'Cork Airport',
#          'position': {'latitude': 51.841381,
#           'longitude': -8.49111,
#           'country': {'name': 'Ireland', 'code': 'IE', 'id': 106},
#           'region': {'city': 'Cork'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344600, 'arrival': 1741349400},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630756783,
#         'number': {'default': 'LM335', 'alternative': None},
#         'callsign': 'LOG88DB',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:50',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344600, 'local': 1741344600}}},
#        'aircraft': {'model': {'code': 'AT76', 'text': 'ATR 72-600'},
#         'registration': 'G-LMTF',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407F4C',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'logo': None},
#        'airline': {'name': 'Loganair (Isle of Man Livery)',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'short': 'Loganair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'CWL', 'icao': 'EGFF'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Cardiff Airport',
#          'position': {'latitude': 51.396469,
#           'longitude': -3.33753,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Cardiff'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344600, 'arrival': 1741350600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630756790,
#         'number': {'default': 'LM315', 'alternative': None},
#         'callsign': 'LOG18FR',
#         'codeshare': ['BA4073', 'SI7315']},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:50',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344600, 'local': 1741344600}}},
#        'aircraft': {'model': {'code': 'E145', 'text': 'Embraer ERJ-145EP'},
#         'registration': 'G-SAJI',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '40080F',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'logo': None},
#        'airline': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'short': 'Loganair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'EXT', 'icao': 'EGTE'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Exeter Airport',
#          'position': {'latitude': 50.73444,
#           'longitude': -3.41388,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Exeter'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344600, 'arrival': 1741349700},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630873639,
#         'number': {'default': 'U2329', 'alternative': None},
#         'callsign': 'EZY374R',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:01',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741345260, 'local': 1741345260}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZTM',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406016',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'BFS', 'icao': 'EGAA'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Belfast International Airport',
#          'position': {'latitude': 54.657501,
#           'longitude': -6.21583,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Belfast'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344600, 'arrival': 1741347600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741345260, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630662464,
#         'number': {'default': 'BA1445', 'alternative': None},
#         'callsign': 'SHT9J',
#         'codeshare': ['AA7228',
#          'AY5970',
#          'IB3733',
#          'MH9825',
#          'QR6285',
#          'KQ4065']},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:00',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741345200, 'local': 1741345200}}},
#        'aircraft': {'model': {'code': 'A21N', 'text': 'Airbus A321-251NX'},
#         'registration': 'G-NEOZ',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407844',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/5.png'},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LHR', 'icao': 'EGLL'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '5', 'baggage': None, 'gate': None},
#          'name': 'London Heathrow Airport',
#          'position': {'latitude': 51.471626,
#           'longitude': -0.467081,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741345200, 'arrival': 1741350900},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741345200, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630712862,
#         'number': {'default': 'FR5663', 'alternative': 'MW5663'},
#         'callsign': 'RYR52NE',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:15',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741346100, 'local': 1741346100}}},
#        'aircraft': {'model': {'code': 'B38M', 'text': 'Boeing 737 MAX 8-200'},
#         'registration': '9H-VUS',
#         'country': {'id': 136,
#          'name': 'Malta',
#          'alpha2': 'MT',
#          'alpha3': 'MLT'},
#         'hex': '4D2369',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Malta Air',
#         'code': {'iata': 'MW', 'icao': 'MAY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/1530.png'},
#        'airline': {'name': 'Ryanair',
#         'code': {'iata': 'FR', 'icao': 'RYR'},
#         'short': 'Ryanair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'AGP', 'icao': 'LEMG'},
#          'timezone': {'name': 'Europe/Madrid',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': '16'},
#          'name': 'Malaga Costa Del Sol Airport',
#          'position': {'latitude': 36.679596,
#           'longitude': -4.496117,
#           'country': {'name': 'Spain', 'code': 'ES', 'id': 209},
#           'region': {'city': 'Malaga'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741346100, 'arrival': 1741358100},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741346100, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630633878,
#         'number': {'default': 'AF1687', 'alternative': 'A51687'},
#         'callsign': 'AFR56RC',
#         'codeshare': ['AM5813',
#          'DL8308',
#          'EY5890',
#          'G35283',
#          'KQ3897',
#          'MK9373',
#          'MU1752',
#          'UX2260',
#          'VS6603']},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:25',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741346700, 'local': 1741346700}}},
#        'aircraft': {'model': {'code': 'E190', 'text': 'Embraer E190LR'},
#         'registration': 'F-HBLA',
#         'country': {'id': 76,
#          'name': 'France',
#          'alpha2': 'FR',
#          'alpha3': 'FRA'},
#         'hex': '398560',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Air France Hop',
#         'code': {'iata': 'A5', 'icao': 'HOP'},
#         'logo': None},
#        'airline': {'name': 'Air France',
#         'code': {'iata': 'AF', 'icao': 'AFR'},
#         'short': 'Air France'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': '2'}},
#         'destination': {'code': {'iata': 'CDG', 'icao': 'LFPG'},
#          'timezone': {'name': 'Europe/Paris',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': '2E', 'baggage': '32', 'gate': None},
#          'name': 'Paris Charles de Gaulle Airport',
#          'position': {'latitude': 49.012516,
#           'longitude': 2.555752,
#           'country': {'name': 'France', 'code': 'FR', 'id': 76},
#           'region': {'city': 'Paris'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741346700, 'arrival': 1741353600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741346700, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630852094,
#         'number': {'default': 'TK1344', 'alternative': None},
#         'callsign': 'THY6ZH',
#         'codeshare': ['6E4227', 'PK5344', 'TG9093']},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:40',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741347600, 'local': 1741347600}}},
#        'aircraft': {'model': {'code': 'A332', 'text': 'Airbus A330-223'},
#         'registration': 'TC-LOH',
#         'country': {'id': 228,
#          'name': 'Turkey',
#          'alpha2': 'TR',
#          'alpha3': 'TUR'},
#         'hex': '4BB1E8',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Turkish Airlines',
#         'code': {'iata': 'TK', 'icao': 'THY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/39.png'},
#        'airline': {'name': 'Turkish Airlines',
#         'code': {'iata': 'TK', 'icao': 'THY'},
#         'short': 'Turkish Airlines'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'IST', 'icao': 'LTFM'},
#          'timezone': {'name': 'Europe/Istanbul',
#           'offset': 10800,
#           'abbr': '+03',
#           'abbrName': None,
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Istanbul Airport',
#          'position': {'latitude': 41.267052,
#           'longitude': 28.729757,
#           'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#           'region': {'city': 'Istanbul'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741346700, 'arrival': 1741362900},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741347600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630699343,
#         'number': {'default': 'EI3653', 'alternative': 'EAG3653'},
#         'callsign': 'EAG53U',
#         'codeshare': ['BA8875', 'QR8261']},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:40',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741347600, 'local': 1741347600}}},
#        'aircraft': {'model': {'code': 'AT76', 'text': 'ATR 72-600'},
#         'registration': 'G-CMJJ',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407E31',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Emerald Airlines UK',
#         'code': {'iata': None, 'icao': 'EAG'},
#         'logo': None},
#        'airline': {'name': 'Aer Lingus Regional',
#         'code': {'iata': 'EI', 'icao': 'EIN'},
#         'short': 'Aer Lingus'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'BHD', 'icao': 'EGAC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Belfast City George Best Airport',
#          'position': {'latitude': 54.61805,
#           'longitude': -5.8725,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Belfast'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741347600, 'arrival': 1741350900},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741347600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630662866,
#         'number': {'default': 'BA2217', 'alternative': 'CJ2217'},
#         'callsign': 'CFE45C',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 12:04',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741349040, 'local': 1741349040}}},
#        'aircraft': {'model': {'code': 'E190', 'text': 'Embraer E190SR'},
#         'registration': 'G-LCAF',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '4079D1',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'BA CityFlyer',
#         'code': {'iata': 'CJ', 'icao': 'CFE'},
#         'logo': None},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LCY', 'icao': 'EGLC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
# ...
#          'alpha3': 'GBR'},
#         'hex': '406011',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'STN', 'icao': 'EGSS'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '1', 'baggage': None, 'gate': None},
#          'name': 'London Stansted Airport',
#          'position': {'latitude': 51.884998,
#           'longitude': 0.235,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741377300, 'arrival': 1741382100},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741377300, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630873645,
#         'number': {'default': 'U2339', 'alternative': None},
#         'callsign': 'EZY16VN',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 19:55',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741377300, 'local': 1741377300}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZOT',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406E65',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'BHX', 'icao': 'EGBB'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': '6', 'gate': '14'},
#          'name': 'Birmingham Airport',
#          'position': {'latitude': 52.45385,
#           'longitude': -1.74802,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Birmingham'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741377300, 'arrival': 1741381500},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741377300, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630713385,
#         'number': {'default': 'FR7352', 'alternative': None},
#         'callsign': None,
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:00',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741377600, 'local': 1741377600}}},
#        'aircraft': {'model': {'code': '7M8', 'text': ''},
#         'hex': '',
#         'registration': '',
#         'serialNo': '',
#         'images': None},
#        'owner': None,
#        'airline': {'name': 'Ryanair',
#         'code': {'iata': 'FR', 'icao': 'RYR'},
#         'short': 'Ryanair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'CRL', 'icao': 'EBCI'},
#          'timezone': {'name': 'Europe/Brussels',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Brussels South Charleroi Airport',
#          'position': {'latitude': 50.459972,
#           'longitude': 4.453121,
#           'country': {'name': 'Belgium', 'code': 'BE', 'id': 22},
#           'region': {'city': 'Brussels'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741377600, 'arrival': 1741383900},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741377600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630770602,
#         'number': {'default': 'BA8719', 'alternative': 'CJ8719'},
#         'callsign': 'CFE18M',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:00',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741377600, 'local': 1741377600}}},
#        'aircraft': {'model': {'code': 'E190', 'text': 'Embraer E190SR'},
#         'registration': 'G-LCYJ',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406222',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'BA CityFlyer',
#         'code': {'iata': 'CJ', 'icao': 'CFE'},
#         'logo': None},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LCY', 'icao': 'EGLC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': '03', 'gate': None},
#          'name': 'London City Airport',
#          'position': {'latitude': 51.505268,
#           'longitude': 0.055278,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741377600, 'arrival': 1741382700},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741377600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5633643056,
#         'number': {'default': 'ZT6565', 'alternative': None},
#         'callsign': 'AWC6565',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:25',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741379100, 'local': 1741379100}}},
#        'aircraft': {'model': {'code': 'B762', 'text': 'Boeing 767-204(BDSF)'},
#         'registration': 'OY-SRK',
#         'country': {'id': 61,
#          'name': 'Denmark',
#          'alpha2': 'DK',
#          'alpha3': 'DNK'},
#         'hex': '45CE4B',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Maersk Air Cargo',
#         'code': {'iata': 'DJ', 'icao': 'SRR'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/599.png'},
#        'airline': {'name': 'Maersk Air Cargo',
#         'code': {'iata': 'DJ', 'icao': 'SRR'},
#         'short': 'Maersk Air Cargo'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'EMA', 'icao': 'EGNX'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Nottingham East Midlands Airport',
#          'position': {'latitude': 52.831108,
#           'longitude': -1.32805,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Nottingham'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741378200, 'arrival': 1741381500},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741379100, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630781761,
#         'number': {'default': 'EI3659', 'alternative': 'EAG3659'},
#         'callsign': 'EAG35E',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:15',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741378500, 'local': 1741378500}}},
#        'aircraft': {'model': {'code': 'AT76', 'text': 'ATR 72-600'},
#         'registration': 'G-CMJM',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407E32',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Emerald Airlines UK',
#         'code': {'iata': None, 'icao': 'EAG'},
#         'logo': None},
#        'airline': {'name': 'Aer Lingus Regional',
#         'code': {'iata': 'EI', 'icao': 'EIN'},
#         'short': 'Aer Lingus'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'BHD', 'icao': 'EGAC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Belfast City George Best Airport',
#          'position': {'latitude': 54.61805,
#           'longitude': -5.8725,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Belfast'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741378500, 'arrival': 1741381800},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741378500, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630699234,
#         'number': {'default': 'EI3259', 'alternative': 'EA3259'},
#         'callsign': 'EAI59LD',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:20',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741378800, 'local': 1741378800}}},
#        'aircraft': {'model': {'code': 'AT76', 'text': 'ATR 72-600'},
#         'registration': 'EI-FSL',
#         'country': {'id': 106,
#          'name': 'Ireland',
#          'alpha2': 'IE',
#          'alpha3': 'IRL'},
#         'hex': '4CA6B2',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Emerald Airlines',
#         'code': {'iata': 'EA', 'icao': 'EAI'},
#         'logo': None},
#        'airline': {'name': 'Aer Lingus Regional',
#         'code': {'iata': 'EI', 'icao': 'EIN'},
#         'short': 'Aer Lingus'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'DUB', 'icao': 'EIDW'},
#          'timezone': {'name': 'Europe/Dublin',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '2', 'baggage': None, 'gate': 'BUS'},
#          'name': 'Dublin Airport',
#          'position': {'latitude': 53.427849,
#           'longitude': -6.255323,
#           'country': {'name': 'Ireland', 'code': 'IE', 'id': 106},
#           'region': {'city': 'Dublin'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741378800, 'arrival': 1741383600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741378800, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}}]}},
#   'weather': {'metar': 'EGPH 070920Z 27003KT 9999 BKN021 10/09 Q1008',
#    'time': 1741339200,
#    'qnh': 1008,
#    'dewpoint': {'celsius': 9, 'fahrenheit': 48},
#    'humidity': 93,
#    'pressure': {'hg': 30, 'hpa': 1008},
#    'sky': {'condition': {'text': 'Overcast'},
#     'visibility': {'km': 99999000, 'mi': 62, 'nmi': 54}},
#    'flight': {'category': 'MVFR'},
#    'wind': {'direction': {'degree': 270, 'text': 'From west'},
#     'speed': {'kmh': 7, 'kts': 4, 'mph': 4, 'text': 'Calm'}},
#    'temp': {'celsius': 10, 'fahrenheit': 50},
#    'elevation': {'m': 41, 'ft': 135},
#    'cached': 1741340027},
#   'aircraftCount': {'ground': 17, 'onGround': {'visible': 7, 'total': 17}},
#   'runways': [{'name': '06',
#     'length': {'ft': 8392, 'm': 2558},
#     'surface': {'code': 'ASPH', 'name': 'Asphalt'}},
#    {'name': '24',
#     'length': {'ft': 8392, 'm': 2558},
#     'surface': {'code': 'ASPH', 'name': 'Asphalt'}}]}}

# %%
import requests

response = requests.get("https://api.flightapi.io/schedule/67cabf7ed8fa5ab514772bf9?mode=departures&iata=EDI&day=1")
print(response.json())
# Out:
# {'airport': {'pluginData': {'details': {'name': 'Edinburgh Airport', 'code': {'iata': 'EDI', 'icao': 'EGPH'}, 'delayIndex': {'arrivals': 0.42, 'departures': 0.71}, 'stats': {'arrivals': {'delayIndex': 0.42, 'delayAvg': 5, 'percentage': {'delayed': 0.1, 'canceled': 0, 'trend': 'down'}, 'recent': {'delayIndex': 0.42, 'delayAvg': 5, 'percentage': {'delayed': 0.1, 'canceled': 0, 'trend': 'down'}, 'quantity': {'onTime': 19, 'delayed': 2, 'canceled': 0}}, 'today': {'percentage': {'delayed': 0.01, 'canceled': 0}, 'quantity': {'onTime': 30, 'delayed': 2, 'canceled': 0}}, 'yesterday': {'percentage': {'delayed': 0.09, 'canceled': 0.01}, 'quantity': {'onTime': 135, 'delayed': 14, 'canceled': 2}}, 'tomorrow': {'percentage': {'canceled': 0}, 'quantity': {'canceled': 0}}}, 'departures': {'delayIndex': 0.71, 'delayAvg': 8, 'percentage': {'delayed': 0.36, 'canceled': 0, 'trend': 'up'}, 'recent': {'delayIndex': 0.71, 'delayAvg': 8, 'percentage': {'delayed': 0.36, 'canceled': 0, 'trend': 'up'}, 'quantity': {'onTime': 14, 'delayed': 8, 'canceled': 0}}, 'today': {'percentage': {'delayed': 0.09, 'canceled': 0}, 'quantity': {'onTime': 37, 'delayed': 16, 'canceled': 0}}, 'yesterday': {'percentage': {'delayed': 0.29, 'canceled': 0.01}, 'quantity': {'onTime': 107, 'delayed': 44, 'canceled': 1}}, 'tomorrow': {'percentage': {'canceled': 0}, 'quantity': {'canceled': 0}}}}, 'position': {'latitude': 55.950001, 'longitude': -3.3725, 'elevation': 135, 'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235}, 'region': {'city': 'Edinburgh'}}, 'timezone': {'name': 'Europe/London', 'offset': 0, 'abbr': 'GMT', 'abbrName': 'Greenwich Mean Time', 'isDst': False}, 'url': {'homepage': 'http://www.edinburghairport.com/', 'webcam': 'https://airportwebcams.net/edinburgh-airport-webcam/', 'wikipedia': 'https://en.wikipedia.org/wiki/Edinburgh_Airport'}, 'airportImages': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/911307_1722256620_tb.jpg', 'link': 'https://www.jetphotos.com/photo/11427326', 'copyright': 'Lonely Neutrino', 'source': 'Jetphotos.com'}, {'src': 'https://cdn.jetphotos.com/200/6/18784_1425933101_tb.jpg', 'link': 'https://www.jetphotos.com/photo/7995810', 'copyright': 'Roger Oldfield', 'source': 'Jetphotos.com'}], 'medium': [{'src': 'https://cdn.jetphotos.com/400/6/911307_1722256620.jpg', 'link': 'https://www.jetphotos.com/photo/11427326', 'copyright': 'Lonely Neutrino', 'source': 'Jetphotos.com'}, {'src': 'https://cdn.jetphotos.com/400/6/18784_1425933101.jpg', 'link': 'https://www.jetphotos.com/photo/7995810', 'copyright': 'Roger Oldfield', 'source': 'Jetphotos.com'}], 'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/911307_1722256620.jpg', 'link': 'https://www.jetphotos.com/photo/11427326', 'copyright': 'Lonely Neutrino', 'source': 'Jetphotos.com'}, {'src': 'https://cdn.jetphotos.com/640cb/6/18784_1425933101.jpg', 'link': 'https://www.jetphotos.com/photo/7995810', 'copyright': 'Roger Oldfield', 'source': 'Jetphotos.com'}]}, 'visible': True}, 'flightdiary': {'url': '/data/airports/edi/reviews', 'ratings': {'avg': 3.93, 'total': 3194}, 'comment': [{'content': "I just had a backpack, so it was straight to security for me. There was a larger queue than the last time, but I was still through in six minutes. No doubt due in large part to no longer requiring to take things from bags.\r\nI was leaving from Gate 21, which is around the corner. I had WiFi connection previously, but when I got to the gate I had none. I don't know if it was a wider issue or just an issue with the gates furthest away from the main body of the departure lounge.", 'author': {'facebookId': None, 'name': 'AlphaMikeEcho'}, 'timestamp': 1738781399}], 'reviews': 143, 'evaluation': 79}, 'schedule': {'departures': {'item': {'current': 100, 'total': 237, 'limit': 100}, 'page': {'current': 1, 'total': 3}, 'timestamp': 1741340640, 'data': [{'flight': {'identification': {'id': None, 'row': 5630662448, 'number': {'default': 'BA1441', 'alternative': None}, 'callsign': 'SHT9Z', 'co ...

# %%
import pprint
arrivals = response.json()
# pprint.pp(arrivals)

arrivals.keys()
# Out:
# dict_keys(['airport', 'airlines', 'aircraftImages'])

# %%
pprint.pp(arrivals)

# %%
pprint.pp(arrivals['airport']['pluginData']['schedule']['departures'].keys())
# Out:
# dict_keys(['item', 'page', 'timestamp', 'data'])

# %%
pprint.pp(arrivals['airport']['pluginData']['schedule']['departures']['data'][0]['flight'])
# Out:
# {'identification': {'id': None,
#                     'row': 5630662448,
#                     'number': {'default': 'BA1441', 'alternative': None},
#                     'callsign': 'SHT9Z',
#                     'codeshare': ['AA6734',
#                                   'AY5942',
#                                   'IB3730',
#                                   'QF3560',
#                                   'QR6283']},
#  'status': {'live': False,
#             'text': 'Estimated dep 10:08',
#             'icon': 'yellow',
#             'estimated': None,
#             'ambiguous': False,
#             'generic': {'status': {'text': 'estimated',
#                                    'type': 'departure',
#                                    'color': 'yellow',
#                                    'diverted': None},
#                         'eventTime': {'utc': 1741342080, 'local': 1741342080}}},
#  'aircraft': {'model': {'code': 'A20N', 'text': 'Airbus A320-251N'},
#               'registration': 'G-TTNL',
#               'country': {'id': 235,
#                           'name': 'United Kingdom',
#                           'alpha2': 'GB',
#                           'alpha3': 'GBR'},
#               'hex': '40792F',
#               'restricted': False,
#               'serialNo': None,
#               'age': {'availability': True},
#               'availability': {'serialNo': True, 'age': True}},
#  'owner': {'name': 'British Airways',
#            'code': {'iata': 'BA', 'icao': 'BAW'},
#            'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/5.png'},
#  'airline': {'name': 'British Airways',
#              'code': {'iata': 'BA', 'icao': 'BAW'},
#              'short': 'British Airways'},
#  'airport': {'origin': {'timezone': {'name': 'Europe/London',
#                                      'offset': 0,
#                                      'abbr': 'GMT',
#                                      'abbrName': 'Greenwich Mean Time',
#                                      'isDst': False},
#                         'info': {'terminal': None,
#                                  'baggage': None,
#                                  'gate': None}},
#              'destination': {'code': {'iata': 'LHR', 'icao': 'EGLL'},
#                              'timezone': {'name': 'Europe/London',
#                                           'offset': 0,
#                                           'abbr': 'GMT',
#                                           'abbrName': 'Greenwich Mean Time',
#                                           'isDst': False},
#                              'info': {'terminal': '5',
#                                       'baggage': None,
#                                       'gate': None},
#                              'name': 'London Heathrow Airport',
#                              'position': {'latitude': 51.471626,
#                                           'longitude': -0.467081,
#                                           'country': {'name': 'United Kingdom',
#                                                       'code': 'GB',
#                                                       'id': 235},
#                                           'region': {'city': 'London'}},
#                              'visible': True},
#              'real': None},
#  'time': {'scheduled': {'departure': 1741341000, 'arrival': 1741346700},
#           'real': {'departure': None, 'arrival': None},
#           'estimated': {'departure': 1741342080, 'arrival': None},
#           'other': {'eta': None, 'duration': None}}}

# %%
# import json
# json.dump(arrivals, open(, 'wb'))
# # data = json.load(open(filename))

filename_airports = "data_airline_edi_7mar2025.json"

import json 
   

# Convert and write JSON object to file
def save_data(filename, data):
    with open(filename, "w") as outfile: 
        json.dump(data, outfile)

save_data(filename, arrivals )

def load_file(filename):
    data = json.load(open(filename))
    return data

load_file(filename_airports)
# Out:
# {'pluginData': {'details': {'name': 'Edinburgh Airport',
#    'code': {'iata': 'EDI', 'icao': 'EGPH'},
#    'delayIndex': {'arrivals': 0.42, 'departures': 0.71},
#    'stats': {'arrivals': {'delayIndex': 0.42,
#      'delayAvg': 5,
#      'percentage': {'delayed': 0.1, 'canceled': 0, 'trend': 'down'},
#      'recent': {'delayIndex': 0.42,
#       'delayAvg': 5,
#       'percentage': {'delayed': 0.1, 'canceled': 0, 'trend': 'down'},
#       'quantity': {'onTime': 19, 'delayed': 2, 'canceled': 0}},
#      'today': {'percentage': {'delayed': 0.01, 'canceled': 0},
#       'quantity': {'onTime': 30, 'delayed': 2, 'canceled': 0}},
#      'yesterday': {'percentage': {'delayed': 0.09, 'canceled': 0.01},
#       'quantity': {'onTime': 135, 'delayed': 14, 'canceled': 2}},
#      'tomorrow': {'percentage': {'canceled': 0}, 'quantity': {'canceled': 0}}},
#     'departures': {'delayIndex': 0.71,
#      'delayAvg': 8,
#      'percentage': {'delayed': 0.36, 'canceled': 0, 'trend': 'up'},
#      'recent': {'delayIndex': 0.71,
#       'delayAvg': 8,
#       'percentage': {'delayed': 0.36, 'canceled': 0, 'trend': 'up'},
#       'quantity': {'onTime': 14, 'delayed': 8, 'canceled': 0}},
#      'today': {'percentage': {'delayed': 0.09, 'canceled': 0},
#       'quantity': {'onTime': 37, 'delayed': 16, 'canceled': 0}},
#      'yesterday': {'percentage': {'delayed': 0.29, 'canceled': 0.01},
#       'quantity': {'onTime': 107, 'delayed': 44, 'canceled': 1}},
#      'tomorrow': {'percentage': {'canceled': 0},
#       'quantity': {'canceled': 0}}}},
#    'position': {'latitude': 55.950001,
#     'longitude': -3.3725,
#     'elevation': 135,
#     'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#     'region': {'city': 'Edinburgh'}},
#    'timezone': {'name': 'Europe/London',
#     'offset': 0,
#     'abbr': 'GMT',
#     'abbrName': 'Greenwich Mean Time',
#     'isDst': False},
#    'url': {'homepage': 'http://www.edinburghairport.com/',
#     'webcam': 'https://airportwebcams.net/edinburgh-airport-webcam/',
#     'wikipedia': 'https://en.wikipedia.org/wiki/Edinburgh_Airport'},
#    'airportImages': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/911307_1722256620_tb.jpg',
#       'link': 'https://www.jetphotos.com/photo/11427326',
#       'copyright': 'Lonely Neutrino',
#       'source': 'Jetphotos.com'},
#      {'src': 'https://cdn.jetphotos.com/200/6/18784_1425933101_tb.jpg',
#       'link': 'https://www.jetphotos.com/photo/7995810',
#       'copyright': 'Roger Oldfield',
#       'source': 'Jetphotos.com'}],
#     'medium': [{'src': 'https://cdn.jetphotos.com/400/6/911307_1722256620.jpg',
#       'link': 'https://www.jetphotos.com/photo/11427326',
#       'copyright': 'Lonely Neutrino',
#       'source': 'Jetphotos.com'},
#      {'src': 'https://cdn.jetphotos.com/400/6/18784_1425933101.jpg',
#       'link': 'https://www.jetphotos.com/photo/7995810',
#       'copyright': 'Roger Oldfield',
#       'source': 'Jetphotos.com'}],
#     'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/911307_1722256620.jpg',
#       'link': 'https://www.jetphotos.com/photo/11427326',
#       'copyright': 'Lonely Neutrino',
#       'source': 'Jetphotos.com'},
#      {'src': 'https://cdn.jetphotos.com/640cb/6/18784_1425933101.jpg',
#       'link': 'https://www.jetphotos.com/photo/7995810',
#       'copyright': 'Roger Oldfield',
#       'source': 'Jetphotos.com'}]},
#    'visible': True},
#   'flightdiary': {'url': '/data/airports/edi/reviews',
#    'ratings': {'avg': 3.93, 'total': 3194},
#    'comment': [{'content': "I just had a backpack, so it was straight to security for me. There was a larger queue than the last time, but I was still through in six minutes. No doubt due in large part to no longer requiring to take things from bags.\r\nI was leaving from Gate 21, which is around the corner. I had WiFi connection previously, but when I got to the gate I had none. I don't know if it was a wider issue or just an issue with the gates furthest away from the main body of the departure lounge.",
#      'author': {'facebookId': None, 'name': 'AlphaMikeEcho'},
#      'timestamp': 1738781399}],
#    'reviews': 143,
#    'evaluation': 79},
#   'schedule': {'departures': {'item': {'current': 100,
#      'total': 237,
#      'limit': 100},
#     'page': {'current': 1, 'total': 3},
#     'timestamp': 1741340640,
#     'data': [{'flight': {'identification': {'id': None,
#         'row': 5630662448,
#         'number': {'default': 'BA1441', 'alternative': None},
#         'callsign': 'SHT9Z',
#         'codeshare': ['AA6734', 'AY5942', 'IB3730', 'QF3560', 'QR6283']},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:08',
#         'icon': 'yellow',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'yellow',
#           'diverted': None},
#          'eventTime': {'utc': 1741342080, 'local': 1741342080}}},
#        'aircraft': {'model': {'code': 'A20N', 'text': 'Airbus A320-251N'},
#         'registration': 'G-TTNL',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '40792F',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/5.png'},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LHR', 'icao': 'EGLL'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '5', 'baggage': None, 'gate': None},
#          'name': 'London Heathrow Airport',
#          'position': {'latitude': 51.471626,
#           'longitude': -0.467081,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741341000, 'arrival': 1741346700},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741342080, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630874374,
#         'number': {'default': 'U23293', 'alternative': None},
#         'callsign': 'EZY85RN',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 09:55',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741341300, 'local': 1741341300}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZTG',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406011',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'GVA', 'icao': 'LSGG'},
#          'timezone': {'name': 'Europe/Zurich',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': '1', 'baggage': '2', 'gate': None},
#          'name': 'Geneva International Airport',
#          'position': {'latitude': 46.23806,
#           'longitude': 6.10895,
#           'country': {'name': 'Switzerland', 'code': 'CH', 'id': 216},
#           'region': {'city': 'Geneva'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741341300, 'arrival': 1741349400},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741341300, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630873569,
#         'number': {'default': 'U2311', 'alternative': None},
#         'callsign': 'EZY87HG',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:15',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741342500, 'local': 1741342500}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZWY',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406B91',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'STN', 'icao': 'EGSS'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '1', 'baggage': None, 'gate': None},
#          'name': 'London Stansted Airport',
#          'position': {'latitude': 51.884998,
#           'longitude': 0.235,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741342500, 'arrival': 1741347300},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741342500, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630664042,
#         'number': {'default': 'BA8715', 'alternative': 'CJ8715'},
#         'callsign': 'CFE57J',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:20',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741342800, 'local': 1741342800}}},
#        'aircraft': {'model': {'code': 'E190', 'text': 'Embraer E190SR'},
#         'registration': 'G-LCYV',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406D4E',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'BA CityFlyer',
#         'code': {'iata': 'CJ', 'icao': 'CFE'},
#         'logo': None},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LCY', 'icao': 'EGLC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': '03', 'gate': None},
#          'name': 'London City Airport',
#          'position': {'latitude': 51.505268,
#           'longitude': 0.055278,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741342800, 'arrival': 1741348200},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741342800, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630874922,
#         'number': {'default': 'U26566', 'alternative': None},
#         'callsign': 'EZY73GD',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:25',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741343100, 'local': 1741343100}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EJCE',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407E61',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LGW', 'icao': 'EGKK'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': 'S', 'baggage': None, 'gate': None},
#          'name': 'London Gatwick Airport',
#          'position': {'latitude': 51.148048,
#           'longitude': -0.19027,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741343100, 'arrival': 1741348500},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741343100, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630803267,
#         'number': {'default': 'LM323', 'alternative': None},
#         'callsign': 'LOG24J',
#         'codeshare': ['BA4103', 'SI7323']},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:48',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344480, 'local': 1741344480}}},
#        'aircraft': {'model': {'code': 'E145', 'text': 'Embraer ERJ-145EP'},
#         'registration': 'G-SAJK',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '4007DC',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'logo': None},
#        'airline': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'short': 'Loganair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'SOU', 'icao': 'EGHI'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Southampton Airport',
#          'position': {'latitude': 50.95026,
#           'longitude': -1.3568,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Southampton'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741343700, 'arrival': 1741348800},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344480, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630874384,
#         'number': {'default': 'U23323', 'alternative': None},
#         'callsign': 'EZY43JU',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:35',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741343700, 'local': 1741343700}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZOT',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406E65',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'CPH', 'icao': 'EKCH'},
#          'timezone': {'name': 'Europe/Copenhagen',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': '3', 'baggage': None, 'gate': None},
#          'name': 'Copenhagen Airport',
#          'position': {'latitude': 55.616959,
#           'longitude': 12.645637,
#           'country': {'name': 'Denmark', 'code': 'DK', 'id': 61},
#           'region': {'city': 'Copenhagen'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741343700, 'arrival': 1741350600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741343700, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630874391,
#         'number': {'default': 'U23319', 'alternative': None},
#         'callsign': 'EZY17QR',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:35',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741343700, 'local': 1741343700}}},
#        'aircraft': {'model': {'code': 'A20N', 'text': 'Airbus A320-251N'},
#         'registration': 'G-UZEE',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '40815C',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'HRG', 'icao': 'HEGN'},
#          'timezone': {'name': 'Africa/Cairo',
#           'offset': 7200,
#           'abbr': 'EET',
#           'abbrName': 'Eastern European Time',
#           'isDst': False},
#          'info': {'terminal': '1', 'baggage': None, 'gate': None},
#          'name': 'Hurghada International Airport',
#          'position': {'latitude': 27.17831,
#           'longitude': 33.799431,
#           'country': {'name': 'Egypt', 'code': 'EG', 'id': 66},
#           'region': {'city': 'Hurghada'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741343700, 'arrival': 1741364100},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741343700, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630677199,
#         'number': {'default': 'D83503', 'alternative': None},
#         'callsign': 'NSZ3503',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:40',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344000, 'local': 1741344000}}},
#        'aircraft': {'model': {'code': 'B738', 'text': 'Boeing 737-8JP'},
#         'registration': 'SE-RRO',
#         'country': {'id': 215,
#          'name': 'Sweden',
#          'alpha2': 'SE',
#          'alpha3': 'SWE'},
#         'hex': '4ACA4F',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Norwegian Air Sweden',
#         'code': {'iata': 'D8', 'icao': 'NSZ'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/1278.png'},
#        'airline': {'name': 'Norwegian (Otto Sverdrup Livery)',
#         'code': {'iata': 'DY', 'icao': 'NOZ'},
#         'short': 'Norwegian'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'CPH', 'icao': 'EKCH'},
#          'timezone': {'name': 'Europe/Copenhagen',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': '3', 'baggage': None, 'gate': None},
#          'name': 'Copenhagen Airport',
#          'position': {'latitude': 55.616959,
#           'longitude': 12.645637,
#           'country': {'name': 'Denmark', 'code': 'DK', 'id': 61},
#           'region': {'city': 'Copenhagen'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344000, 'arrival': 1741350300},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344000, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630712140,
#         'number': {'default': 'FR3732', 'alternative': 'MW3732'},
#         'callsign': 'RYR4GM',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:50',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344600, 'local': 1741344600}}},
#        'aircraft': {'model': {'code': 'B738', 'text': 'Boeing 737-8AS'},
#         'registration': '9H-QDU',
#         'country': {'id': 136,
#          'name': 'Malta',
#          'alpha2': 'MT',
#          'alpha3': 'MLT'},
#         'hex': '4D226A',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Malta Air',
#         'code': {'iata': 'MW', 'icao': 'MAY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/1530.png'},
#        'airline': {'name': 'Ryanair',
#         'code': {'iata': 'FR', 'icao': 'RYR'},
#         'short': 'Ryanair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'ORK', 'icao': 'EICK'},
#          'timezone': {'name': 'Europe/Dublin',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': '3', 'gate': '1A'},
#          'name': 'Cork Airport',
#          'position': {'latitude': 51.841381,
#           'longitude': -8.49111,
#           'country': {'name': 'Ireland', 'code': 'IE', 'id': 106},
#           'region': {'city': 'Cork'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344600, 'arrival': 1741349400},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630756783,
#         'number': {'default': 'LM335', 'alternative': None},
#         'callsign': 'LOG88DB',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:50',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344600, 'local': 1741344600}}},
#        'aircraft': {'model': {'code': 'AT76', 'text': 'ATR 72-600'},
#         'registration': 'G-LMTF',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407F4C',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'logo': None},
#        'airline': {'name': 'Loganair (Isle of Man Livery)',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'short': 'Loganair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'CWL', 'icao': 'EGFF'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Cardiff Airport',
#          'position': {'latitude': 51.396469,
#           'longitude': -3.33753,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Cardiff'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344600, 'arrival': 1741350600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630756790,
#         'number': {'default': 'LM315', 'alternative': None},
#         'callsign': 'LOG18FR',
#         'codeshare': ['BA4073', 'SI7315']},
#        'status': {'live': False,
#         'text': 'Estimated dep 10:50',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741344600, 'local': 1741344600}}},
#        'aircraft': {'model': {'code': 'E145', 'text': 'Embraer ERJ-145EP'},
#         'registration': 'G-SAJI',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '40080F',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'logo': None},
#        'airline': {'name': 'Loganair',
#         'code': {'iata': 'LM', 'icao': 'LOG'},
#         'short': 'Loganair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'EXT', 'icao': 'EGTE'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Exeter Airport',
#          'position': {'latitude': 50.73444,
#           'longitude': -3.41388,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Exeter'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344600, 'arrival': 1741349700},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741344600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630873639,
#         'number': {'default': 'U2329', 'alternative': None},
#         'callsign': 'EZY374R',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:01',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741345260, 'local': 1741345260}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZTM',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406016',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'BFS', 'icao': 'EGAA'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Belfast International Airport',
#          'position': {'latitude': 54.657501,
#           'longitude': -6.21583,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Belfast'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741344600, 'arrival': 1741347600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741345260, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630662464,
#         'number': {'default': 'BA1445', 'alternative': None},
#         'callsign': 'SHT9J',
#         'codeshare': ['AA7228',
#          'AY5970',
#          'IB3733',
#          'MH9825',
#          'QR6285',
#          'KQ4065']},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:00',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741345200, 'local': 1741345200}}},
#        'aircraft': {'model': {'code': 'A21N', 'text': 'Airbus A321-251NX'},
#         'registration': 'G-NEOZ',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407844',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/5.png'},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LHR', 'icao': 'EGLL'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '5', 'baggage': None, 'gate': None},
#          'name': 'London Heathrow Airport',
#          'position': {'latitude': 51.471626,
#           'longitude': -0.467081,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741345200, 'arrival': 1741350900},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741345200, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630712862,
#         'number': {'default': 'FR5663', 'alternative': 'MW5663'},
#         'callsign': 'RYR52NE',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:15',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741346100, 'local': 1741346100}}},
#        'aircraft': {'model': {'code': 'B38M', 'text': 'Boeing 737 MAX 8-200'},
#         'registration': '9H-VUS',
#         'country': {'id': 136,
#          'name': 'Malta',
#          'alpha2': 'MT',
#          'alpha3': 'MLT'},
#         'hex': '4D2369',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Malta Air',
#         'code': {'iata': 'MW', 'icao': 'MAY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/1530.png'},
#        'airline': {'name': 'Ryanair',
#         'code': {'iata': 'FR', 'icao': 'RYR'},
#         'short': 'Ryanair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'AGP', 'icao': 'LEMG'},
#          'timezone': {'name': 'Europe/Madrid',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': '16'},
#          'name': 'Malaga Costa Del Sol Airport',
#          'position': {'latitude': 36.679596,
#           'longitude': -4.496117,
#           'country': {'name': 'Spain', 'code': 'ES', 'id': 209},
#           'region': {'city': 'Malaga'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741346100, 'arrival': 1741358100},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741346100, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630633878,
#         'number': {'default': 'AF1687', 'alternative': 'A51687'},
#         'callsign': 'AFR56RC',
#         'codeshare': ['AM5813',
#          'DL8308',
#          'EY5890',
#          'G35283',
#          'KQ3897',
#          'MK9373',
#          'MU1752',
#          'UX2260',
#          'VS6603']},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:25',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741346700, 'local': 1741346700}}},
#        'aircraft': {'model': {'code': 'E190', 'text': 'Embraer E190LR'},
#         'registration': 'F-HBLA',
#         'country': {'id': 76,
#          'name': 'France',
#          'alpha2': 'FR',
#          'alpha3': 'FRA'},
#         'hex': '398560',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Air France Hop',
#         'code': {'iata': 'A5', 'icao': 'HOP'},
#         'logo': None},
#        'airline': {'name': 'Air France',
#         'code': {'iata': 'AF', 'icao': 'AFR'},
#         'short': 'Air France'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': '2'}},
#         'destination': {'code': {'iata': 'CDG', 'icao': 'LFPG'},
#          'timezone': {'name': 'Europe/Paris',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': '2E', 'baggage': '32', 'gate': None},
#          'name': 'Paris Charles de Gaulle Airport',
#          'position': {'latitude': 49.012516,
#           'longitude': 2.555752,
#           'country': {'name': 'France', 'code': 'FR', 'id': 76},
#           'region': {'city': 'Paris'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741346700, 'arrival': 1741353600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741346700, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630852094,
#         'number': {'default': 'TK1344', 'alternative': None},
#         'callsign': 'THY6ZH',
#         'codeshare': ['6E4227', 'PK5344', 'TG9093']},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:40',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741347600, 'local': 1741347600}}},
#        'aircraft': {'model': {'code': 'A332', 'text': 'Airbus A330-223'},
#         'registration': 'TC-LOH',
#         'country': {'id': 228,
#          'name': 'Turkey',
#          'alpha2': 'TR',
#          'alpha3': 'TUR'},
#         'hex': '4BB1E8',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Turkish Airlines',
#         'code': {'iata': 'TK', 'icao': 'THY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/39.png'},
#        'airline': {'name': 'Turkish Airlines',
#         'code': {'iata': 'TK', 'icao': 'THY'},
#         'short': 'Turkish Airlines'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'IST', 'icao': 'LTFM'},
#          'timezone': {'name': 'Europe/Istanbul',
#           'offset': 10800,
#           'abbr': '+03',
#           'abbrName': None,
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Istanbul Airport',
#          'position': {'latitude': 41.267052,
#           'longitude': 28.729757,
#           'country': {'name': 'Turkey', 'code': 'TR', 'id': 228},
#           'region': {'city': 'Istanbul'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741346700, 'arrival': 1741362900},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741347600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630699343,
#         'number': {'default': 'EI3653', 'alternative': 'EAG3653'},
#         'callsign': 'EAG53U',
#         'codeshare': ['BA8875', 'QR8261']},
#        'status': {'live': False,
#         'text': 'Estimated dep 11:40',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741347600, 'local': 1741347600}}},
#        'aircraft': {'model': {'code': 'AT76', 'text': 'ATR 72-600'},
#         'registration': 'G-CMJJ',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407E31',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Emerald Airlines UK',
#         'code': {'iata': None, 'icao': 'EAG'},
#         'logo': None},
#        'airline': {'name': 'Aer Lingus Regional',
#         'code': {'iata': 'EI', 'icao': 'EIN'},
#         'short': 'Aer Lingus'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'BHD', 'icao': 'EGAC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Belfast City George Best Airport',
#          'position': {'latitude': 54.61805,
#           'longitude': -5.8725,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Belfast'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741347600, 'arrival': 1741350900},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741347600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630662866,
#         'number': {'default': 'BA2217', 'alternative': 'CJ2217'},
#         'callsign': 'CFE45C',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 12:04',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741349040, 'local': 1741349040}}},
#        'aircraft': {'model': {'code': 'E190', 'text': 'Embraer E190SR'},
#         'registration': 'G-LCAF',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '4079D1',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'BA CityFlyer',
#         'code': {'iata': 'CJ', 'icao': 'CFE'},
#         'logo': None},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LCY', 'icao': 'EGLC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
# ...
#          'alpha3': 'GBR'},
#         'hex': '406011',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'STN', 'icao': 'EGSS'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '1', 'baggage': None, 'gate': None},
#          'name': 'London Stansted Airport',
#          'position': {'latitude': 51.884998,
#           'longitude': 0.235,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741377300, 'arrival': 1741382100},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741377300, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630873645,
#         'number': {'default': 'U2339', 'alternative': None},
#         'callsign': 'EZY16VN',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 19:55',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741377300, 'local': 1741377300}}},
#        'aircraft': {'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#         'registration': 'G-EZOT',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406E65',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/42.png'},
#        'airline': {'name': 'easyJet',
#         'code': {'iata': 'U2', 'icao': 'EZY'},
#         'short': 'easyJet'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'BHX', 'icao': 'EGBB'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': '6', 'gate': '14'},
#          'name': 'Birmingham Airport',
#          'position': {'latitude': 52.45385,
#           'longitude': -1.74802,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Birmingham'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741377300, 'arrival': 1741381500},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741377300, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630713385,
#         'number': {'default': 'FR7352', 'alternative': None},
#         'callsign': None,
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:00',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741377600, 'local': 1741377600}}},
#        'aircraft': {'model': {'code': '7M8', 'text': ''},
#         'hex': '',
#         'registration': '',
#         'serialNo': '',
#         'images': None},
#        'owner': None,
#        'airline': {'name': 'Ryanair',
#         'code': {'iata': 'FR', 'icao': 'RYR'},
#         'short': 'Ryanair'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'CRL', 'icao': 'EBCI'},
#          'timezone': {'name': 'Europe/Brussels',
#           'offset': 3600,
#           'abbr': 'CET',
#           'abbrName': 'Central European Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Brussels South Charleroi Airport',
#          'position': {'latitude': 50.459972,
#           'longitude': 4.453121,
#           'country': {'name': 'Belgium', 'code': 'BE', 'id': 22},
#           'region': {'city': 'Brussels'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741377600, 'arrival': 1741383900},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741377600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630770602,
#         'number': {'default': 'BA8719', 'alternative': 'CJ8719'},
#         'callsign': 'CFE18M',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:00',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741377600, 'local': 1741377600}}},
#        'aircraft': {'model': {'code': 'E190', 'text': 'Embraer E190SR'},
#         'registration': 'G-LCYJ',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '406222',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'BA CityFlyer',
#         'code': {'iata': 'CJ', 'icao': 'CFE'},
#         'logo': None},
#        'airline': {'name': 'British Airways',
#         'code': {'iata': 'BA', 'icao': 'BAW'},
#         'short': 'British Airways'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'LCY', 'icao': 'EGLC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': '03', 'gate': None},
#          'name': 'London City Airport',
#          'position': {'latitude': 51.505268,
#           'longitude': 0.055278,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'London'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741377600, 'arrival': 1741382700},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741377600, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5633643056,
#         'number': {'default': 'ZT6565', 'alternative': None},
#         'callsign': 'AWC6565',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:25',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741379100, 'local': 1741379100}}},
#        'aircraft': {'model': {'code': 'B762', 'text': 'Boeing 767-204(BDSF)'},
#         'registration': 'OY-SRK',
#         'country': {'id': 61,
#          'name': 'Denmark',
#          'alpha2': 'DK',
#          'alpha3': 'DNK'},
#         'hex': '45CE4B',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Maersk Air Cargo',
#         'code': {'iata': 'DJ', 'icao': 'SRR'},
#         'logo': 'https://images.flightradar24.com/assets/airlines/logotypes/599.png'},
#        'airline': {'name': 'Maersk Air Cargo',
#         'code': {'iata': 'DJ', 'icao': 'SRR'},
#         'short': 'Maersk Air Cargo'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'EMA', 'icao': 'EGNX'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Nottingham East Midlands Airport',
#          'position': {'latitude': 52.831108,
#           'longitude': -1.32805,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Nottingham'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741378200, 'arrival': 1741381500},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741379100, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630781761,
#         'number': {'default': 'EI3659', 'alternative': 'EAG3659'},
#         'callsign': 'EAG35E',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:15',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741378500, 'local': 1741378500}}},
#        'aircraft': {'model': {'code': 'AT76', 'text': 'ATR 72-600'},
#         'registration': 'G-CMJM',
#         'country': {'id': 235,
#          'name': 'United Kingdom',
#          'alpha2': 'GB',
#          'alpha3': 'GBR'},
#         'hex': '407E32',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Emerald Airlines UK',
#         'code': {'iata': None, 'icao': 'EAG'},
#         'logo': None},
#        'airline': {'name': 'Aer Lingus Regional',
#         'code': {'iata': 'EI', 'icao': 'EIN'},
#         'short': 'Aer Lingus'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'BHD', 'icao': 'EGAC'},
#          'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None},
#          'name': 'Belfast City George Best Airport',
#          'position': {'latitude': 54.61805,
#           'longitude': -5.8725,
#           'country': {'name': 'United Kingdom', 'code': 'GB', 'id': 235},
#           'region': {'city': 'Belfast'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741378500, 'arrival': 1741381800},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741378500, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}},
#      {'flight': {'identification': {'id': None,
#         'row': 5630699234,
#         'number': {'default': 'EI3259', 'alternative': 'EA3259'},
#         'callsign': 'EAI59LD',
#         'codeshare': None},
#        'status': {'live': False,
#         'text': 'Estimated dep 20:20',
#         'icon': 'green',
#         'estimated': None,
#         'ambiguous': False,
#         'generic': {'status': {'text': 'estimated',
#           'type': 'departure',
#           'color': 'green',
#           'diverted': None},
#          'eventTime': {'utc': 1741378800, 'local': 1741378800}}},
#        'aircraft': {'model': {'code': 'AT76', 'text': 'ATR 72-600'},
#         'registration': 'EI-FSL',
#         'country': {'id': 106,
#          'name': 'Ireland',
#          'alpha2': 'IE',
#          'alpha3': 'IRL'},
#         'hex': '4CA6B2',
#         'restricted': False,
#         'serialNo': None,
#         'age': {'availability': True},
#         'availability': {'serialNo': True, 'age': True}},
#        'owner': {'name': 'Emerald Airlines',
#         'code': {'iata': 'EA', 'icao': 'EAI'},
#         'logo': None},
#        'airline': {'name': 'Aer Lingus Regional',
#         'code': {'iata': 'EI', 'icao': 'EIN'},
#         'short': 'Aer Lingus'},
#        'airport': {'origin': {'timezone': {'name': 'Europe/London',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': None, 'baggage': None, 'gate': None}},
#         'destination': {'code': {'iata': 'DUB', 'icao': 'EIDW'},
#          'timezone': {'name': 'Europe/Dublin',
#           'offset': 0,
#           'abbr': 'GMT',
#           'abbrName': 'Greenwich Mean Time',
#           'isDst': False},
#          'info': {'terminal': '2', 'baggage': None, 'gate': 'BUS'},
#          'name': 'Dublin Airport',
#          'position': {'latitude': 53.427849,
#           'longitude': -6.255323,
#           'country': {'name': 'Ireland', 'code': 'IE', 'id': 106},
#           'region': {'city': 'Dublin'}},
#          'visible': True},
#         'real': None},
#        'time': {'scheduled': {'departure': 1741378800, 'arrival': 1741383600},
#         'real': {'departure': None, 'arrival': None},
#         'estimated': {'departure': 1741378800, 'arrival': None},
#         'other': {'eta': None, 'duration': None}}}}]}},
#   'weather': {'metar': 'EGPH 070920Z 27003KT 9999 BKN021 10/09 Q1008',
#    'time': 1741339200,
#    'qnh': 1008,
#    'dewpoint': {'celsius': 9, 'fahrenheit': 48},
#    'humidity': 93,
#    'pressure': {'hg': 30, 'hpa': 1008},
#    'sky': {'condition': {'text': 'Overcast'},
#     'visibility': {'km': 99999000, 'mi': 62, 'nmi': 54}},
#    'flight': {'category': 'MVFR'},
#    'wind': {'direction': {'degree': 270, 'text': 'From west'},
#     'speed': {'kmh': 7, 'kts': 4, 'mph': 4, 'text': 'Calm'}},
#    'temp': {'celsius': 10, 'fahrenheit': 50},
#    'elevation': {'m': 41, 'ft': 135},
#    'cached': 1741340027},
#   'aircraftCount': {'ground': 17, 'onGround': {'visible': 7, 'total': 17}},
#   'runways': [{'name': '06',
#     'length': {'ft': 8392, 'm': 2558},
#     'surface': {'code': 'ASPH', 'name': 'Asphalt'}},
#    {'name': '24',
#     'length': {'ft': 8392, 'm': 2558},
#     'surface': {'code': 'ASPH', 'name': 'Asphalt'}}]}}
